# %% [markdown]
# <a href="https://colab.research.google.com/github/PratapPawarGit/Data-Science/blob/main/machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Machine Learning**
#
# ml is process of teaching computer to learn from historical data and use those patterns and make predictions on new data,

# %% [markdown]
# historical data ->
# data preparation->
# eda->
# feature selection ->
# deploy
