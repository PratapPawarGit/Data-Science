# %% [markdown]
# <a href="https://colab.research.google.com/github/PratapPawarGit/Data-Science/blob/main/DataClanning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings                  #to avoid warnings
warnings.filterwarnings('ignore')

# %%
weather=pd.read_csv("data_clean.csv")
weather
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
weather.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
weather.describe()
# Out:
#        Unnamed: 0       Ozone     Solar.R        Wind         Day    Year  \
# count  158.000000  120.000000  151.000000  158.000000  158.000000   158.0
# mean    79.500000   41.583333  185.403974    9.957595   16.006329  2010.0
# std     45.754781   32.620709   88.723103    3.511261    8.997166     0.0
# min      1.000000    1.000000    7.000000    1.700000    1.000000  2010.0
# 25%     40.250000   18.000000  119.000000    7.400000    8.000000  2010.0
# 50%     79.500000   30.500000  197.000000    9.700000   16.000000  2010.0
# 75%    118.750000   61.500000  257.000000   11.875000   24.000000  2010.0
# max    158.000000  168.000000  334.000000   20.700000   31.000000  2010.0
#
#              Temp
# count  158.000000
# mean    77.727848
# std      9.377877
# min     56.000000
# 25%     72.000000
# 50%     78.500000
# 75%     84.000000
# max     97.000000

# %%
weather.reset_index(drop=True,inplace=True)

# %%
weather.rename(columns={"Solar.R":"Solar","Temp":"Temperature"},inplace=True)
weather
# Out:
#      Unnamed: 0  Ozone  Solar  Wind Temp C Month  Day  Year  Temperature  \
# 0             1   41.0  190.0   7.4     67     5    1  2010           67
# 1             2   36.0  118.0   8.0     72     5    2  2010           72
# 2             3   12.0  149.0  12.6     74     5    3  2010           74
# 3             4   18.0  313.0  11.5     62     5    4  2010           62
# 4             5    NaN    NaN  14.3     56     5    5  2010           56
# ..          ...    ...    ...   ...    ...   ...  ...   ...          ...
# 153         154   41.0  190.0   7.4     67     5    1  2010           67
# 154         155   30.0  193.0   6.9     70     9   26  2010           70
# 155         156    NaN  145.0  13.2     77     9   27  2010           77
# 156         157   14.0  191.0  14.3     75     9   28  2010           75
# 157         158   18.0  131.0   8.0     76     9   29  2010           76
#
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ...

# %%
# type conversions
weather.Month.value_counts()
# Out:
# Month
# 9      34
# 5      31
# 8      31
# 7      31
# 6      30
# May     1
# Name: count, dtype: int64

# %%
weather.loc[weather["Month"]=='May',"Month"]=5

# %%
weather.Month.unique()
# Out:
# array(['5', 5, '6', '7', '8', '9'], dtype=object)

# %%
weather['Temp C'].unique()
# Out:
# array(['67', '72', '74', '62', '56', '66', '65', '59', '61', '69', 'C',
#        '68', '58', '64', '57', '73', '81', '79', '76', '78', '84', '85',
#        '82', '87', '90', '93', '92', '80', '77', '75', '83', '88', '89',
#        '91', '86', '97', '94', '96', '71', '63', '70'], dtype=object)

# %%
weather['Month']=pd.to_numeric(weather['Month'],errors='coerce')

# %%
weather['Temp C']=pd.to_numeric(weather['Month'],errors='coerce')

# %%
weather['Temp C'].unique()
# Out:
# array([5, 6, 7, 8, 9])

# %%
weather['Month'].unique()
# Out:
# array([5, 6, 7, 8, 9])

# %%
weather.dtypes
# Out:
# Unnamed: 0       int64
# Ozone          float64
# Solar          float64
# Wind           float64
# Temp C           int64
# Month            int64
# Day              int64
# Year             int64
# Temperature      int64
# Weather         object
# dtype: object

# %%
weather['Year'].unique()
# Out:
# array([2010])

# %%
weather.drop(['Temp C',"Unnamed: 0","Year"],axis=1,inplace=True)

# %%
weather
# Out:
#      Ozone  Solar  Wind  Month  Day  Temperature Weather
# 0     41.0  190.0   7.4      5    1           67       S
# 1     36.0  118.0   8.0      5    2           72       C
# 2     12.0  149.0  12.6      5    3           74      PS
# 3     18.0  313.0  11.5      5    4           62       S
# 4      NaN    NaN  14.3      5    5           56       S
# ..     ...    ...   ...    ...  ...          ...     ...
# 153   41.0  190.0   7.4      5    1           67       C
# 154   30.0  193.0   6.9      9   26           70      PS
# 155    NaN  145.0  13.2      9   27           77       S
# 156   14.0  191.0  14.3      9   28           75       S
# 157   18.0  131.0   8.0      9   29           76       C
#
# [158 rows x 7 columns]

# %%
corr=weather.select_dtypes(include='number').corr()

sns.heatmap(corr,annot=True,cmap='rainbow')
# Out:
# <Axes: >

# %%
weather.isnull().sum()
# Out:
# Ozone          38
# Solar           7
# Wind            0
# Month           0
# Day             0
# Temperature     0
# Weather         3
# dtype: int64

# %% [markdown]
# **missing value treatment
#
# ---

# %%
weather['Ozone'].plot(kind='box')
# Out:
# <Axes: >

# %%
oz_med=weather['Ozone'].median()
oz_med
# Out:
# 30.5

# %%
weather["Ozone"]=weather['Ozone'].fillna(oz_med)

# %%
# weather['Solar'].fillna(weather['Solar'].mean(),inplace=True)

# %%
weather['Ozone'].isnull().sum()
# Out:
# np.int64(0)

# %%
weather['Solar'].plot(kind='box')
# Out:
# <Axes: >

# %%
weather['Solar'].fillna(weather['Solar'].mean(),inplace=True)

# %%
weather['Solar'].isnull().sum()
# Out:
# np.int64(0)

# %%
weather['Weather'].mode()[0]
# Out:
# 'S'

# %%
weather['Weather']=weather['Weather'].fillna(weather['Weather'].mode()[0])

# %%
weather.dropna(inplace=True)

# %%
weather.isnull().sum()
# Out:
# Ozone          0
# Solar          0
# Wind           0
# Month          0
# Day            0
# Temperature    0
# Weather        0
# dtype: int64

# %% [markdown]
# **Outlier Treatment**

# %%
# To detect iutliers
import matplotlib.pyplot as plt
for i in weather.columns:
  if weather[i].dtypes!='object':
    plt.boxplot(weather[i])
    plt.title(i)
    plt.show()

# %%
import numpy as np
Q1 =np.percentile(weather['Ozone'],25)
Q3 =weather['Ozone'].quantile(0.75)
Q1,Q3
IQR =Q3-Q1

UE = Q3 +1.5*(IQR)

LE = Q1 -1.5*(IQR)

# %%
weather[weather['Ozone']>UE]
# Out:
#      Ozone  Solar  Wind  Month  Day  Temperature Weather
# 29   115.0  223.0   5.7      5   30           79       C
# 61   135.0  269.0   4.1      7    1           84       S
# 68    97.0  267.0   6.3      7    8           92      PS
# 69    97.0  272.0   5.7      7    9           92       C
# 70    85.0  175.0   7.4      7   10           89      PS
# 85   108.0  223.0   8.0      7   25           85      PS
# 88    82.0  213.0   7.4      7   28           88       S
# 98   122.0  255.0   4.0      8    7           89       C
# 99    89.0  229.0  10.3      8    8           90      PS
# 100  110.0  207.0   8.0      8    9           90       C
# 116  168.0  238.0   3.4      8   25           81      PS
# 120  118.0  225.0   2.3      8   29           94       S
# 121   84.0  237.0   6.3      8   30           96       S
# 122   85.0  188.0   6.3      8   31           94       C
# 123   96.0  167.0   6.9      9    1           91       C
# ...

# %%
weather[weather['Ozone']<LE]
# Out:
# Empty DataFrame
# Columns: [Ozone, Solar, Wind, Month, Day, Temperature, Weather]
# Index: []

# %%
weather.loc[weather['Ozone']>UE,"Ozone"]=UE

# %%
plt.boxplot(weather['Ozone'])
plt.show()

# %%
# percentile method

ue =weather['Wind'].quantile(0.95)
le =weather['Wind'].quantile(0.05)
ue,le
# Out:
# (np.float64(15.5), np.float64(4.6))

# %%
weather.loc[weather['Wind']>ue,"Wind"]
# Out:
# 8      20.1
# 17     18.4
# 21     16.6
# 24     16.6
# 33     16.1
# 47     20.7
# 147    16.6
# Name: Wind, dtype: float64

# %%
weather.loc[weather['Wind']<le,"Wind"]
# Out:
# 52     1.7
# 61     4.1
# 98     4.0
# 116    3.4
# 120    2.3
# 125    2.8
# Name: Wind, dtype: float64

# %%
weather.loc[weather['Wind']>3*ue,"Wind"]=3*ue
weather['Wind'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
weather.head()
# Out:
#    Ozone       Solar  Wind  Month  Day  Temperature Weather
# 0   41.0  190.000000   7.4      5    1           67       S
# 1   36.0  118.000000   8.0      5    2           72       C
# 2   12.0  149.000000  12.6      5    3           74      PS
# 3   18.0  313.000000  11.5      5    4           62       S
# 4   30.5  185.403974  14.3      5    5           56       S

# %% [markdown]
# **Transformations**

# %%
weather.head()
# Out:
#    Ozone       Solar  Wind  Month  Day  Temperature Weather
# 0   41.0  190.000000   7.4      5    1           67       S
# 1   36.0  118.000000   8.0      5    2           72       C
# 2   12.0  149.000000  12.6      5    3           74      PS
# 3   18.0  313.000000  11.5      5    4           62       S
# 4   30.5  185.403974  14.3      5    5           56       S

# %%
# encoding using panda dummy functions
df =pd.get_dummies(data = weather,columns =['Weather'])
df
# Out:
#      Ozone       Solar  Wind  Month  Day  Temperature  Weather_C  Weather_PS  \
# 0     41.0  190.000000   7.4      5    1           67      False       False
# 1     36.0  118.000000   8.0      5    2           72       True       False
# 2     12.0  149.000000  12.6      5    3           74      False        True
# 3     18.0  313.000000  11.5      5    4           62      False       False
# 4     30.5  185.403974  14.3      5    5           56      False       False
# ..     ...         ...   ...    ...  ...          ...        ...         ...
# 153   41.0  190.000000   7.4      5    1           67       True       False
# 154   30.0  193.000000   6.9      9   26           70      False        True
# 155   30.5  145.000000  13.2      9   27           77      False       False
# 156   14.0  191.000000  14.3      9   28           75      False       False
# 157   18.0  131.000000   8.0      9   29           76       True       False
#
#      Weather_S
# 0         True
# ...

# %% [markdown]
# **Scaling the data**

# %%
from sklearn.preprocessing import StandardScaler ,MinMaxScaler
sc = StandardScaler()

# %%
weather_numeric = weather.select_dtypes(include=['int64','float64'])

# %%
sc.fit_transform(weather_numeric)
# Out:
# array([[ 2.01690286e-01,  5.31653544e-02, -7.30713873e-01,
#         -1.41690441e+00, -1.67319835e+00, -1.14759017e+00],
#        [-2.11563237e-02, -7.79707460e-01, -5.59291761e-01,
#         -1.41690441e+00, -1.56169884e+00, -6.12725133e-01],
#        [-1.09082005e+00, -4.21109443e-01,  7.54944424e-01,
#         -1.41690441e+00, -1.45019933e+00, -3.98779120e-01],
#        [-8.23404118e-01,  1.47598975e+00,  4.40670554e-01,
#         -1.41690441e+00, -1.33869982e+00, -1.68245520e+00],
#        [-2.66287594e-01,  0.00000000e+00,  1.24064041e+00,
#         -1.41690441e+00, -1.22720031e+00, -2.32429324e+00],
#        [-3.77710899e-01,  0.00000000e+00,  1.41206252e+00,
#         -1.41690441e+00, -1.11570080e+00, -1.25456317e+00],
#        [-6.00557508e-01,  1.31404225e+00, -3.87869650e-01,
#         -1.41690441e+00, -1.00420129e+00, -1.36153618e+00],
#        [-7.78834796e-01, -9.99493342e-01,  1.09778865e+00,
#         -1.41690441e+00, -8.92701779e-01, -2.00337422e+00],
# ...

# %%
sc.fit_transform(df)
# Out:
# array([[ 0.20169029,  0.05316535, -0.73071387, ..., -0.6704784 ,
#         -0.65070994,  1.24434203],
#        [-0.02115632, -0.77970746, -0.55929176, ...,  1.49147236,
#         -0.65070994, -0.80363756],
#        [-1.09082005, -0.42110944,  0.75494442, ..., -0.6704784 ,
#          1.53678305, -0.80363756],
#        ...,
#        [-0.26628759, -0.46738015,  0.92636654, ..., -0.6704784 ,
#         -0.65070994,  1.24434203],
#        [-1.00168141,  0.06473303,  1.24064041, ..., -0.6704784 ,
#         -0.65070994,  1.24434203],
#        [-0.82340412, -0.62932765, -0.55929176, ...,  1.49147236,
#         -0.65070994, -0.80363756]])

# %%
pd.DataFrame(sc.fit_transform(df))
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.201690  0.053165 -0.730714 -1.416904 -1.673198 -1.147590 -0.670478
# 1   -0.021156 -0.779707 -0.559292 -1.416904 -1.561699 -0.612725  1.491472
# 2   -1.090820 -0.421109  0.754944 -1.416904 -1.450199 -0.398779 -0.670478
# 3   -0.823404  1.475990  0.440671 -1.416904 -1.338700 -1.682455 -0.670478
# 4   -0.266288  0.000000  1.240640 -1.416904 -1.227200 -2.324293 -0.670478
# ..        ...       ...       ...       ...       ...       ...       ...
# 153  0.201690  0.053165 -0.730714 -1.416904 -1.673198 -1.147590  1.491472
# 154 -0.288572  0.087868 -0.873566  1.372764  1.114289 -0.826671 -0.670478
# 155 -0.266288 -0.467380  0.926367  1.372764  1.225789 -0.077860 -0.670478
# 156 -1.001681  0.064733  1.240640  1.372764  1.337288 -0.291806 -0.670478
# 157 -0.823404 -0.629328 -0.559292  1.372764  1.448788 -0.184833  1.491472
#
#             7         8
# 0   -0.650710  1.244342
# 1   -0.650710 -0.803638
# ...

# %%
df.columns
# Out:
# Index(['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Temperature', 'Weather_C',
#        'Weather_PS', 'Weather_S'],
#       dtype='object')

# %%
scaled_data =pd.DataFrame(sc.fit_transform(df),columns=df.columns)
scaled_data
# Out:
#         Ozone     Solar      Wind     Month       Day  Temperature  Weather_C  \
# 0    0.201690  0.053165 -0.730714 -1.416904 -1.673198    -1.147590  -0.670478
# 1   -0.021156 -0.779707 -0.559292 -1.416904 -1.561699    -0.612725   1.491472
# 2   -1.090820 -0.421109  0.754944 -1.416904 -1.450199    -0.398779  -0.670478
# 3   -0.823404  1.475990  0.440671 -1.416904 -1.338700    -1.682455  -0.670478
# 4   -0.266288  0.000000  1.240640 -1.416904 -1.227200    -2.324293  -0.670478
# ..        ...       ...       ...       ...       ...          ...        ...
# 153  0.201690  0.053165 -0.730714 -1.416904 -1.673198    -1.147590   1.491472
# 154 -0.288572  0.087868 -0.873566  1.372764  1.114289    -0.826671  -0.670478
# 155 -0.266288 -0.467380  0.926367  1.372764  1.225789    -0.077860  -0.670478
# 156 -1.001681  0.064733  1.240640  1.372764  1.337288    -0.291806  -0.670478
# 157 -0.823404 -0.629328 -0.559292  1.372764  1.448788    -0.184833   1.491472
#
#      Weather_PS  Weather_S
# ...

# %%
scaled_data.describe()
# Out:
#               Ozone         Solar          Wind         Month           Day  \
# count  1.580000e+02  1.580000e+02  1.580000e+02  1.580000e+02  1.580000e+02
# mean  -1.236704e-16  1.236704e-16 -2.923119e-16 -1.798842e-16  6.745659e-17
# std    1.003180e+00  1.003180e+00  1.003180e+00  1.003180e+00  1.003180e+00
# min   -1.581083e+00 -2.063720e+00 -2.359224e+00 -1.416904e+00 -1.673198e+00
# 25%   -6.896962e-01 -6.755984e-01 -7.307139e-01 -7.194873e-01 -8.927018e-01
# 50%   -2.662876e-01  8.208455e-02 -7.359578e-02 -2.207016e-02 -7.056931e-04
# 75%    3.799676e-01  8.050644e-01  5.478094e-01  6.753470e-01  8.912904e-01
# max    1.984463e+00  1.718911e+00  3.069143e+00  1.372764e+00  1.671787e+00
#
#         Temperature     Weather_C    Weather_PS     Weather_S
# count  1.580000e+02  1.580000e+02  1.580000e+02  1.580000e+02
# mean   2.473408e-16 -6.464590e-17 -9.275281e-17  6.956461e-17
# std    1.003180e+00  1.003180e+00  1.003180e+00  1.003180e+00
# ...

# %%
mn = MinMaxScaler()

# %%
df.columns
# Out:
# Index(['Ozone', 'Solar', 'Wind', 'Month', 'Day', 'Temperature', 'Weather_C',
#        'Weather_PS', 'Weather_S'],
#       dtype='object')

# %%
minmax_scaled =pd.DataFrame(mn.fit_transform(df),columns =df.columns)
minmax_scaled   # converting values into range 0 and 1
# Out:
#        Ozone     Solar      Wind  Month       Day  Temperature  Weather_C  \
# 0    0.50000  0.559633  0.300000    0.0  0.000000     0.268293        0.0
# 1    0.43750  0.339450  0.331579    0.0  0.033333     0.390244        1.0
# 2    0.13750  0.434251  0.573684    0.0  0.066667     0.439024        0.0
# 3    0.21250  0.935780  0.515789    0.0  0.100000     0.146341        0.0
# 4    0.36875  0.545578  0.663158    0.0  0.133333     0.000000        0.0
# ..       ...       ...       ...    ...       ...          ...        ...
# 153  0.50000  0.559633  0.300000    0.0  0.000000     0.268293        1.0
# 154  0.36250  0.568807  0.273684    1.0  0.833333     0.341463        0.0
# 155  0.36875  0.422018  0.605263    1.0  0.866667     0.512195        0.0
# 156  0.16250  0.562691  0.663158    1.0  0.900000     0.463415        0.0
# 157  0.21250  0.379205  0.331579    1.0  0.933333     0.487805        1.0
#
#      Weather_PS  Weather_S
# 0           0.0        1.0
# ...

# %%
minmax_scaled.describe()
# Out:
#             Ozone       Solar        Wind       Month         Day  \
# count  158.000000  158.000000  158.000000  158.000000  158.000000
# mean     0.443434    0.545578    0.434610    0.507911    0.500211
# std      0.281354    0.265207    0.184803    0.359605    0.299906
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.250000    0.366972    0.300000    0.250000    0.233333
# 50%      0.368750    0.567278    0.421053    0.500000    0.500000
# 75%      0.550000    0.758410    0.535526    0.750000    0.766667
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
#        Temperature   Weather_C  Weather_PS   Weather_S
# count   158.000000  158.000000  158.000000  158.000000
# mean      0.529948    0.310127    0.297468    0.392405
# std       0.228729    0.464016    0.458598    0.489839
# min       0.000000    0.000000    0.000000    0.000000
# 25%       0.390244    0.000000    0.000000    0.000000
# ...

# %%
#eda important
#1.data collection
#2.normal distribution and its charisteristics
