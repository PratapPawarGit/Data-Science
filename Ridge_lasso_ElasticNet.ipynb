# %% [markdown]
# <a href="https://colab.research.google.com/github/PratapPawarGit/Data-Science/blob/main/Ridge_lasso_ElasticNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
data=pd.read_csv("mtcars.csv")
data.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
x=data.drop('mpg',axis=1)
y=data['mpg']

# %%
x
# Out:
#     cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0     6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1     6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2     4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3     6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4     8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5     6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6     8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7     4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8     4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9     6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# 13    8  275.8  180  3.07  3.780  18.00   0   0     3     3
# 14    8  472.0  205  2.93  5.250  17.98   0   0     3     4
# ...

# %%
y
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
lr=LinearRegression()

model_lr=lr.fit(x_train,y_train)
y_pred=model_lr.predict(x_test)
r2_score(y_pred,y_test)
# Out:
# 0.46907205194196877

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)

# %%
y_tr_pred=model_lr.predict(x_train)
r2_score(y_tr_pred,y_train)
# Out:
# 0.9286971800002553

# %%
model_lr.coef_
# Out:
# array([ 1.87348075,  0.01152686, -0.01312608,  3.44043172, -3.24293367,
#         0.86017616,  0.44103927,  1.51229472,  5.26551409, -2.13861236])

# %%
df_lr=pd.DataFrame({"fearures":x.columns,"Coefficient":model_lr.coef_})
df_lr
# Out:
#   fearures  Coefficient
# 0      cyl     1.873481
# 1     disp     0.011527
# 2       hp    -0.013126
# 3     drat     3.440432
# 4       wt    -3.242934
# 5     qsec     0.860176
# 6       vs     0.441039
# 7       am     1.512295
# 8     gear     5.265514
# 9     carb    -2.138612

# %%
plt.bar(x="fearures",height="Coefficient",data=df_lr)
# Out:
# <BarContainer object of 10 artists>

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score
ridge=Ridge(alpha=20)

model_rd=ridge.fit(x_train,y_train)
y_pred=model_ridge.predict(x_test)
r2_score(y_pred,y_test)
# Out:
# 0.7497988221955951

# %%
y_tr_pred_rd=ridge.predict(x_train)
r2_score(y_tr_pred_rd,y_train)
# Out:
# 0.7899062202997698

# %%
df_rd=pd.DataFrame({"fearures":x.columns,"Coefficient":model_rd.coef_})
df_rd
# Out:
#   fearures  Coefficient
# 0      cyl    -0.259153
# 1     disp    -0.027687
# 2       hp    -0.010273
# 3     drat     0.229287
# 4       wt    -0.625640
# 5     qsec    -0.148037
# 6       vs     0.056264
# 7       am     0.254296
# 8     gear     0.208292
# 9     carb    -0.747559

# %%
plt.bar(x="fearures",height="Coefficient",data=df_rd)
# Out:
# <BarContainer object of 10 artists>

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score
lasso=Lasso(alpha=0.5)

model_ls=lasso.fit(x_train,y_train)
y_pred_ls=model_ls.predict(x_test)
r2_score(y_pred_ls,y_test)
# Out:
# 0.7217443549412139

# %%
y_tr_pred_ls=lasso.predict(x_train)
r2_score(y_tr_pred_rd,y_train)
# Out:
# 0.7899062202997698

# %%
df_ls=pd.DataFrame({"fearures":x.columns,"Coefficient":model_ls.coef_})
df_ls
# Out:
#   fearures  Coefficient
# 0      cyl    -0.000000
# 1     disp    -0.030751
# 2       hp    -0.004802
# 3     drat     0.000000
# 4       wt    -1.258638
# 5     qsec    -0.000000
# 6       vs     0.000000
# 7       am     0.000000
# 8     gear     0.000000
# 9     carb    -0.781018

# %%
plt.bar(x="fearures",height="Coefficient",data=df_ls)
# Out:
# <BarContainer object of 10 artists>

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import r2_score
elastic=Elastic(alpha=20)

model_ls=lasso.fit(x_train,y_train)
y_pred=model_ls.predict(x_test)
r2_score(y_pred,y_test)
